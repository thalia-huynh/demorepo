# %% [markdown]
# ### Mini-Max Sum

# %% [markdown]
# Given 5 positive integers, find the min and max values that can be calculated by adding exactly 4 of the 5 integers.<br><br>
# Sample Input:<br>
# 1 2 3 4 5<br><br>
# Sample Output:<br>
# 16 24

# %%
def miniMaxSum(arr):
    arr.sort()
    min_sum = sum(arr[:4])
    max_sum = sum(arr[1:])
    print(min_sum, max_sum)

# %%
miniMaxSum([1,2, 3, 4, 5])
# Out:
# 10 14

# %% [markdown]
# <b>Notes</b><br>
# - <i>arr.sort()</i> sorts original list in place while <i>sorted(arr)</i> returns a new list.
# - Originally ended with <i>return min_sum, max_sum</i> which resulted in output of <i>10, 14</i> but output needed to be <i>10 14</i> which was accomplished with <i>print(min_sum, max_sum)</i>.

# %% [markdown]
# ### Birthday Cake Candles

# %% [markdown]
# ![Screen%20Shot%202023-02-10%20at%2011.00.54%20AM.png](attachment:Screen%20Shot%202023-02-10%20at%2011.00.54%20AM.png)

# %%
def birthdayCakeCandles(candles):
    max_height = max(candles)
    candle_count = 0
    for i in range(candles_count):
        if candles[i] == max_height:
            candle_count += 1
        else:
            pass
    return candle_count

# %%
# another person's code
def birthdayCakeCandles(candles):
    # Write your code here
    return candles.count(max(candles))

# %% [markdown]
# ### Time conversion

# %% [markdown]
# ![Screen%20Shot%202023-02-13%20at%208.41.26%20AM.png](attachment:Screen%20Shot%202023-02-13%20at%208.41.26%20AM.png)

# %%
def timeConversions(s):
    if 'AM' in s:
        if '12:' in s:
            return '00' + s[2:-2]
        else:
            return s[:-2]
    elif 'PM' in s:
        if '12:' in s:
            return s[:-2]
        else:
            hour = str(int(s[0:2]) + 12)
            return hour + s[2:-2]

# %%
timeConversions('07:40:03AM')
# Out:
# '07:40:03'

# %% [markdown]
# #### Notes
# - using <i>print()</i> gave incorrect answer
